# %% [markdown]
# #Python program to Draw Pie Chart

# %%
# !pip install matplot

# %%
import matplotlib.pylab as p

s = [35, 25, 20, 10, 10]
k = ['Python', 'Java', 'C++', 'JavaScript', 'Ruby']
p.pie(s, labels=k)
p.show()
